# %% [markdown]
# # EDA Demo Notebook

# %%
import pandas as pd
from src import eda
df = pd.read_csv('data/customer_support_tickets_example.csv')
eda.summary_statistics(df)

# %%
eda.missing_values(df)

# %%
for fig in eda.plot_numeric_distributions(df):
    fig.show()

# %%
eda.correlation_heatmap(df).show()
